# %%
import pandas as pd
from ifrs17_template.template import *

# %%
df
# Out:
#      DataNode AocType Novelty AmountType  AccidentYear EstimateType  \
# 0       DT1.1      AM       C        ICO           NaN           BE
# 1       DT1.1      AM       C        NIC           NaN           BE
# 2       DT1.1      AM       C         PR           NaN           BE
# 3       DT1.1      AM       C       None           NaN            F
# 4       DT1.1      AM       C       None           NaN            L
# ...       ...     ...     ...        ...           ...          ...
# 1238    DT5.1      AM       C       None           0.0            C
# 1239    DT5.1     EOP       C       None           0.0           DA
# 1240    DT5.1     EOP       C       None           0.0            C
# 1241    DT5.1     BOP       N       None           0.0            C
# 1242    DT5.1      IA       N       None           0.0            C
#
#      EconomicBasis       Value  Year  Month  ... FunctionalCurrency  \
# 0                L    0.000000  2021      3  ...                CHF
# 1                L    0.000000  2021      3  ...                CHF
# 2                L    0.000000  2021      3  ...                CHF
# 3                L    1.000000  2021      3  ...                CHF
# 4             None -180.431356  2021      3  ...                CHF
# ...            ...         ...   ...    ...  ...                ...
# 1238          None  -82.022711  2020     12  ...                CHF
# 1239          None   -5.156552  2020     12  ...                CHF
# 1240          None   42.968114  2020     12  ...                CHF
# 1241          None  139.908492  2020     12  ...                CHF
# 1242          None    0.082333  2020     12  ...                CHF
#
#      LineOfBusiness ValuationApproach  OciType AnnualCohort LiabilityType  \
# 0               ANN               BBA  Default         2020           LRC
# 1               ANN               BBA  Default         2020           LRC
# 2               ANN               BBA  Default         2020           LRC
# 3               ANN               BBA  Default         2020           LRC
# 4               ANN               BBA  Default         2020           LRC
# ...             ...               ...      ...          ...           ...
# 1238            ANN               BBA  Default         2020           LRC
# 1239            ANN               BBA  Default         2020           LRC
# 1240            ANN               BBA  Default         2020           LRC
# 1241            ANN               BBA  Default         2020           LRC
# 1242            ANN               BBA  Default         2020           LRC
#
#       Profitability Portfolio YieldCurveName Partner
# 0                 P       DT1
# 1                 P       DT1
# 2                 P       DT1
# 3                 P       DT1
# 4                 P       DT1
# ...             ...       ...            ...     ...
# 1238              P       DT5
# 1239              P       DT5
# 1240              P       DT5
# 1241              P       DT5
# 1242              P       DT5
#
# [1243 rows x 22 columns]

# %%
df_2103 = df.loc[(df['Year'] == 2021) & (df['Month'] == 3)]

# %%
df_BE = df_2103.loc[df['EstimateType'] == 'BE'][['AocType', 'Novelty', 'AmountType', 'EconomicBasis', 'Value', 'LiabilityType']]
PVs = df_BE.set_index(['Novelty', 'AocType', 'EconomicBasis', 'LiabilityType'])['Value'].groupby(level=list(range(4))).sum().unstack(level=[-1, -2])
PVs
# Out:
# LiabilityType           LIC         LRC                     LIC
# EconomicBasis             L           L           C           C
# Novelty AocType
# C       AM         0.000000    0.000000         NaN         NaN
#         CF         0.000000    0.000000         NaN         NaN
#         CL         0.000000   74.994992   74.987448         NaN
#         EA         0.000000    0.000000         NaN         NaN
#         EOP      269.775343 -383.924048 -383.810302  269.439639
# I       BOP        0.000000    0.000000         NaN         NaN
#         CF       -60.083941  249.832118  249.832118  -60.083941
#         CRU        0.000000    0.000000         NaN         NaN
#         IA         0.109789   -0.366044   -0.366044    0.109789
#         MC         0.000000    0.000000         NaN         NaN
#         RCU        0.000000    0.000000         NaN         NaN
#         YCU        0.000000    0.000000    0.522604   -0.223803
# N       BOP       59.935110   59.895192   59.738697   59.838185
#         CF       -15.267421  -15.534843  -15.534843  -15.267421
#         EV        44.962557  245.798806  245.498160   44.906607
#         IA         0.027447    0.037419    0.093247    0.068421

# %%
df_RA = df_2103.loc[df['EstimateType'] == 'RA'][['AocType', 'Novelty', 'AmountType', 'EconomicBasis', 'Value', 'LiabilityType']]
RA = df_RA.set_index(['Novelty', 'AocType', 'LiabilityType', 'EconomicBasis'])['Value'].groupby(level=list(range(4))).sum().unstack(level=[-1, -2])
RA
# Out:
# EconomicBasis            C          L          C          L
# LiabilityType          LRC        LRC        LIC        LIC
# Novelty AocType
# C       CL      -22.453303 -22.481279        NaN        NaN
#         EOP      89.813213  89.925114  22.453303  22.481279
# I       CF      -30.000000 -30.000000  -6.000000  -6.000000
#         IA        0.054895   0.054895   0.010979   0.010979
#         YCU      -0.111901        NaN  -0.022380        NaN
# N       BOP      59.838185  59.935110  11.967637  11.987022
#         CF      -15.000000 -15.000000  -3.000000  -3.000000
#         EV      -22.453303 -22.481279  -4.490661  -4.496256
#         IA        0.068421   0.027447   0.013684   0.005489

# %%
df_WA = df_2103.loc[df['EstimateType'] == 'A'][['AocType', 'Novelty', 'AmountType', 'Value', 'LiabilityType']]
WA = df_WA.set_index(['AocType', 'AmountType' , 'LiabilityType'])['Value'].groupby(level=list(range(3))).sum().unstack(level=[-1])
WA
# Out:
# LiabilityType        LIC    LRC
# AocType AmountType
# CF      ACA          NaN  -70.0
#         AEA          NaN  -35.0
#         ICO          NaN  -42.0
#         NIC        -82.0 -350.0
#         PR           NaN  450.0

# %%
df_AAOA = df_2103.loc[(df['EstimateType'] == 'AA') | (df['EstimateType'] == 'OA')][['AocType', 'Novelty', 'AmountType', 'Value', 'EstimateType']]
AAOA = df_AAOA.set_index(['AocType', 'AmountType', 'EstimateType'])['Value'].groupby(level=list(range(3))).sum().unstack(level=[-1])
AAOA
# Out:
# EstimateType         AA    OA
# AocType AmountType
# CF      NIC        -4.0  -8.0
#         PR          6.5   5.5
# WO      NIC         5.0  12.5
#         PR          3.5  17.0

# %%
df_DA = df_2103.loc[df['EstimateType'] == 'DA'][['AocType', 'Novelty', 'AmountType', 'Value', 'EstimateType']]
DA = df_DA.set_index(['AocType', 'AmountType', 'EstimateType'])['Value'].groupby(level=list(range(3))).sum().unstack(level=[-1])
DA
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_2103.loc[df['EstimateType'] == 'DA']
# Out:
# Empty DataFrame
# Columns: [DataNode, AocType, Novelty, AmountType, AccidentYear, EstimateType, EconomicBasis, Value, Year, Month, DisplayName, ContractualCurrency, FunctionalCurrency, LineOfBusiness, ValuationApproach, OciType, AnnualCohort, LiabilityType, Profitability, Portfolio, YieldCurveName, Partner]
# Index: []
#
# [0 rows x 22 columns]
